# %%
import os
import pickle
import torch
import numpy as np
from math import ceil
from model_vc import Generator


def pad_seq(x, base=32):
    len_out = int(base * ceil(float(x.shape[0])/base))
    len_pad = len_out - x.shape[0]
    assert len_pad >= 0
    return np.pad(x, ((0,len_pad),(0,0)), 'constant'), len_pad

device = 'cuda:0'
G = Generator(32,256,512,32).eval().to(device)

g_checkpoint = torch.load('assets/autovc.ckpt', map_location=device)
G.load_state_dict(g_checkpoint['model'])

metadata = pickle.load(open('assets/metadata.pkl', "rb"))

spect_vc = []

for sbmt_i in metadata:
             
    x_org = sbmt_i[2]
    print('pre-pad', x_org.shape)
    x_org, len_pad = pad_seq(x_org)
    print('post-pad', x_org.shape, len_pad)
    uttr_org = torch.from_numpy(x_org[np.newaxis, :, :]).to(device)
    emb_org = torch.from_numpy(sbmt_i[1][np.newaxis, :]).to(device)
    
    for sbmt_j in metadata:
                   
        emb_trg = torch.from_numpy(sbmt_j[1][np.newaxis, :]).to(device)
        
        with torch.no_grad():
            print('G inputs', uttr_org.shape, emb_org.shape, emb_trg.shape)
            _, x_identic_psnt, _ = G(uttr_org, emb_org, emb_trg)
            print('G output', x_identic_psnt.shape)
            
        if len_pad == 0:
            uttr_trg = x_identic_psnt[0, 0, :, :].cpu().numpy()
        else:
            uttr_trg = x_identic_psnt[0, 0, :-len_pad, :].cpu().numpy()
        
        print(uttr_trg.shape)
        print('{}x{}'.format(sbmt_i[0], sbmt_j[0]))
        spect_vc.append( ('{}x{}'.format(sbmt_i[0], sbmt_j[0]), uttr_trg) )
        print('-----------------')
    print('=================')
        
        
with open('results/results.pkl', 'wb') as handle:
    pickle.dump(spect_vc, handle)
# Out:
# pre-pad (90, 80)
# post-pad (96, 80) 6
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (90, 80)
# p225xp225
# -----------------
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (90, 80)
# p225xp228
# -----------------
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (90, 80)
# p225xp256
# -----------------
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (90, 80)
# p225xp270
# -----------------
# ...
# pre-pad (89, 80)
# post-pad (96, 80) 7
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (89, 80)
# p228xp225
# -----------------
# G inputs torch.Size([1, 96, 80]) torch.Size([1, 256]) torch.Size([1, 256])
# G output torch.Size([1, 1, 96, 80])
# (89, 80)
# ...

# %%
len(metadata)
# Out:
# 4
